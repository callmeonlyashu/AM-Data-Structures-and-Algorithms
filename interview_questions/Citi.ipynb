# %%
X = 11
def a():
    print(X)
    
def b():
    X = 10
    print(X)
    
class c:
    X = 55
    def m(self):
        X = 45
        self.x = 65
        
        
print(X)
a()
print(X)
b()
print(X)
obj = c()
print(X)
print(obj.X)
# Out:
# 11
# 11
# 11
# 10
# 11
# 11
# 55

# %%
result = {('a', 100), ('c', 101)}
l = ['a', 'b', 'c', 'd']

Output: [100, None, 101, None]
