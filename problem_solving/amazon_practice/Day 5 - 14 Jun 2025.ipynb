# %%
#!/bin/python3

import math
import os
import random
import re
import sys


#
# Complete the 'processLogs' function below.
#
# The function is expected to return a STRING_ARRAY.
# The function accepts following parameters:
#  1. STRING_ARRAY logs
#  2. INTEGER threshold
#

def processLogs(logs, threshold):
    
    # TODO: Optimization Required.
    
    transactions = {}
    result = []
    for log_row in logs:
        transaction_info = log_row.split(" ")
        sender = int(transaction_info[0])
        receiver = int(transaction_info[1])
        if sender in transactions:
            transactions[sender] += 1
        else:
            transactions[sender] = 1
        
        if sender != receiver:
            if receiver in transactions:
                transactions[receiver] += 1
            else:
                transactions[receiver] = 1
    
    # TODO:  Come back and do this in single loop above, 
    result = []
    for user, transaction_count in transactions.items():
        if  transaction_count >=  threshold:
            result.append(user)
    
    result.sort()    
    result = [str(t) for t in result]         
    return result
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    logs_count = int(input().strip())

    logs = []

    for _ in range(logs_count):
        logs_item = input()
        logs.append(logs_item)

    threshold = int(input().strip())

    result = processLogs(logs, threshold)

    fptr.write('\n'.join(result))
    fptr.write('\n')

    fptr.close()
