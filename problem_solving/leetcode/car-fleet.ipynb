# %% [markdown]
# Link: https://leetcode.com/problems/car-fleet/description/

# %%
from typing import List
class Solution:
    def carFleet(self, target: int, position: List[int], speed: List[int]) -> int:
        total_cars = len(position)

        position_stack = []
        for i in range(total_cars):
            time = (target - position[i]) / speed[i]
            position_stack.append((position[i], speed[i]))
        
        position_stack = sorted(position_stack, key=lambda x: x[0], reverse=True)
 
        stack = []
        for p, s in position_stack: 
            stack.append((target - p) / s)
            if len(stack) >= 2 and stack[-1] <= stack[-2]:
                stack.pop()

        return len(stack)
