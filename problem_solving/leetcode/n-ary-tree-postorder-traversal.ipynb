# %% [markdown]
# Link: https://leetcode.com/problems/n-ary-tree-postorder-traversal/submissions/1823062687/

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, val: Optional[int] = None, children: Optional[List['Node']] = None):
        self.val = val
        self.children = children
"""
from typing import Optional, List

class Node:
    def __init__(self, val: Optional[int] = None, children: Optional[List['Node']] = None):
        self.val = val
        self.children = children

class Solution:
    def postorder(self, root: 'Node') -> List[int]:
        
        res = []
        def traversal(childs, res):
            if not childs:
                return

            for child in childs:
                traversal(child.children, res)
                res.append(child.val)
            
        
        if root:
            traversal(root.children, res)
            res.append(root.val)
        return res
